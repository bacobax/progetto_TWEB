# %%
from constants import *

# %%
game_id_converting_to_mongodb_Object_id()
# Out:
# /Users/francescobassignana/Desktop/unito/terzo_anno/TWEB/progetto_TWEB/solution/data_cleaning/constants.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '65730a7dc402ff2c45820206' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   d["d"].loc[mask, "game_id"] = new_id
# REMAINING: 65215 | TIME: 0.030019044876098633
# REMAINING: 65214 | TIME: 0.09838390350341797
# REMAINING: 65213 | TIME: 0.09852218627929688
# REMAINING: 65212 | TIME: 0.09922981262207031
# REMAINING: 65211 | TIME: 0.10085105895996094
# REMAINING: 65210 | TIME: 0.10032367706298828
# REMAINING: 65209 | TIME: 0.0983281135559082
# REMAINING: 65208 | TIME: 0.09903979301452637
# REMAINING: 65207 | TIME: 0.10028481483459473
# REMAINING: 65206 | TIME: 0.098175048828125
# REMAINING: 65205 | TIME: 0.09965395927429199
# REMAINING: 65204 | TIME: 0.09810376167297363
# REMAINING: 65203 | TIME: 0.09844303131103516
# ...
